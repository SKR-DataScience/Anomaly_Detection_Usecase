# %% [markdown]
# # **[Chapter 11]**
# **┗ 전력사용 이상 사용 패턴 탐지**
# ---
# > **목차(Context)**
#
# * 문제상황 및 데이터 살펴보기
# * 문제해결 프로세스 정의
# * 🥉Session 1 - 「Data 전처리 및 EDA」
# * 🥈Session 2 - 「주중 vs 주말 전력사용 분석」
# * 🥇Session 3 - 「이상 탐지 모델링」

# %%
# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# ▶ 경로 설정 (※ Colab을 활성화시켰다면 보통 Colab Notebooks 폴더가 자동 생성)
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Anomaly Detection (FC)/Step 3. 도메인별 이상탐지 실습/[02] Chapter 11. 전력사용 이상 사용 패턴 탐지")
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/Colab Notebooks/Anomaly Detection (FC)/Step 3. 도메인별 이상탐지 실습/[02] Chapter 11. 전력사용 이상 사용 패턴 탐지'

# %% [markdown]
# ## **문제상황 및 데이터 살펴보기**
# ---
# > **시나리오** 💡⚡
# ```
# A사는 이번에 큰 투자비용을 들여 스마트빌딩을 구축했다. 스마트빌딩은 BEMS 시스템 즉 Building Energy Management System이
# 구축되어 있어 에너지 자원을 효율적으로 사용할 수 있으며, 사용되는 에너지의 데이터를 모니터링 할 수 있는 장점을 가지고 있다.
# BEMS를 활용하여 전력사용 데이터를 활용하여 이상 탐지 모델링을 수행하고, 전력 사용을 효율적으로 이용하고자 한다.
# ```

# %% [markdown]
# > **데이터 살펴보기**
#
# * 스마트빌딩 전력사용 데이터
# * 데이터 명세 ⬇
#
# |Column|Description|
# |:---|:---|
# |date|날짜|
# |Floor(n)_z(n)_val| 층/Zone/전기사용제품|

# %%
df.shape
# Out:
# (790560, 192)

# %%
# ▶ pd.set option
import pandas as pd 
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)  

df = pd.read_pickle('chapter11_df.gz')
df.head()
# Out:
#                      Floor1_z1_Light(kW)  Floor1_z1_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                12.94               18.56
# 2018-07-01 00:01:00                12.97               18.55
# 2018-07-01 00:02:00                12.97               18.55
# 2018-07-01 00:03:00                12.98               18.58
# 2018-07-01 00:04:00                13.01               18.60
#
#                      Floor1_z2_AC1(kW)  Floor1_z2_AC2(kW)  Floor1_z2_AC3(kW)  \
# Date
# 2018-07-01 00:00:00              45.24               0.01               0.01
# 2018-07-01 00:01:00              45.28               0.02               0.01
# 2018-07-01 00:02:00              45.24               0.01               0.01
# 2018-07-01 00:03:00              45.26               0.02               0.01
# 2018-07-01 00:04:00              45.22               0.02               0.01
#
#                      Floor1_z2_AC4(kW)  Floor1_z2_Light(kW)  \
# Date
# 2018-07-01 00:00:00               0.00                13.76
# 2018-07-01 00:01:00               0.01                13.76
# 2018-07-01 00:02:00               0.01                13.79
# 2018-07-01 00:03:00               0.00                13.81
# 2018-07-01 00:04:00               0.01                13.83
#
#                      Floor1_z2_Plug(kW)  Floor1_z3_Light(kW)  \
# Date
# 2018-07-01 00:00:00               17.64                10.92
# 2018-07-01 00:01:00               17.21                10.95
# 2018-07-01 00:02:00               17.18                10.94
# 2018-07-01 00:03:00               16.64                10.94
# 2018-07-01 00:04:00               15.69                10.97
#
#                      Floor1_z3_Plug(kW)  Floor1_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                0.89                35.76
# 2018-07-01 00:01:00                0.87                35.81
# 2018-07-01 00:02:00                0.86                35.78
# 2018-07-01 00:03:00                0.85                35.83
# 2018-07-01 00:04:00                0.85                35.86
#
#                      Floor2_z1_AC1(kW)  Floor2_z1_Light(kW)  \
# Date
# 2018-07-01 00:00:00                0.0                 0.01
# 2018-07-01 00:01:00                0.0                 0.01
# 2018-07-01 00:02:00                0.0                 0.01
# 2018-07-01 00:03:00                0.0                 0.01
# 2018-07-01 00:04:00                0.0                 0.01
#
#                      Floor2_z1_Plug(kW)  Floor2_z1_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                0.15              58.93
# 2018-07-01 00:01:00                0.15              58.91
# 2018-07-01 00:02:00                0.15              58.94
# 2018-07-01 00:03:00                0.15              58.94
# 2018-07-01 00:04:00                0.15              58.94
#
#                      Floor2_z1_S1(degC)  Floor2_z1_S1(lux)  Floor2_z2_AC1(kW)  \
# Date
# 2018-07-01 00:00:00               28.36                0.0               1.08
# 2018-07-01 00:01:00               28.36                0.0               1.07
# 2018-07-01 00:02:00               28.36                0.0               0.88
# 2018-07-01 00:03:00               28.36                0.0               1.06
# 2018-07-01 00:04:00               28.36                0.0               1.06
#
#                      Floor2_z2_AC10(kW)  Floor2_z2_AC11(kW)  \
# Date
# 2018-07-01 00:00:00                1.07                 0.0
# 2018-07-01 00:01:00                1.06                 0.0
# 2018-07-01 00:02:00                0.88                 0.0
# 2018-07-01 00:03:00                1.05                 0.0
# 2018-07-01 00:04:00                1.06                 0.0
#
#                      Floor2_z2_AC12(kW)  Floor2_z2_AC13(kW)  \
# Date
# 2018-07-01 00:00:00                 0.0                 0.0
# 2018-07-01 00:01:00                 0.0                 0.0
# 2018-07-01 00:02:00                 0.0                 0.0
# 2018-07-01 00:03:00                 0.0                 0.0
# 2018-07-01 00:04:00                 0.0                 0.0
#
#                      Floor2_z2_AC14(kW)  Floor2_z2_AC2(kW)  Floor2_z2_AC3(kW)  \
# Date
# 2018-07-01 00:00:00                 0.0                0.0                0.0
# 2018-07-01 00:01:00                 0.0                0.0                0.0
# 2018-07-01 00:02:00                 0.0                0.0                0.0
# 2018-07-01 00:03:00                 0.0                0.0                0.0
# 2018-07-01 00:04:00                 0.0                0.0                0.0
#
#                      Floor2_z2_AC4(kW)  Floor2_z2_AC5(kW)  Floor2_z2_AC6(kW)  \
# Date
# 2018-07-01 00:00:00                0.0               1.29               1.26
# 2018-07-01 00:01:00                0.0               1.30               1.24
# 2018-07-01 00:02:00                0.0               1.09               1.03
# 2018-07-01 00:03:00                0.0               1.29               1.23
# 2018-07-01 00:04:00                0.0               1.26               1.24
#
#                      Floor2_z2_AC7(kW)  Floor2_z2_AC8(kW)  Floor2_z2_AC9(kW)  \
# Date
# 2018-07-01 00:00:00               0.87               0.92               0.96
# 2018-07-01 00:01:00               0.88               0.91               0.97
# 2018-07-01 00:02:00               0.74               0.75               0.82
# 2018-07-01 00:03:00               0.87               0.90               0.96
# 2018-07-01 00:04:00               0.84               0.91               0.94
#
#                      Floor2_z2_Light(kW)  Floor2_z2_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  0.0                0.10
# 2018-07-01 00:01:00                  0.0                0.10
# 2018-07-01 00:02:00                  0.0                0.09
# 2018-07-01 00:03:00                  0.0                0.09
# 2018-07-01 00:04:00                  0.0                0.09
#
#                      Floor2_z2_S1(RH%)  Floor2_z2_S1(degC)  Floor2_z2_S1(lux)  \
# Date
# 2018-07-01 00:00:00              64.89               28.85                0.0
# 2018-07-01 00:01:00              64.89               28.85                0.0
# 2018-07-01 00:02:00              64.89               28.85                0.0
# 2018-07-01 00:03:00              64.89               28.85                0.0
# 2018-07-01 00:04:00              64.90               28.84                0.0
#
#                      Floor2_z3_Light(kW)  Floor2_z3_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                 0.01                0.32
# 2018-07-01 00:01:00                 0.01                0.32
# 2018-07-01 00:02:00                 0.01                0.28
# 2018-07-01 00:03:00                 0.01                0.32
# 2018-07-01 00:04:00                 0.01                0.32
#
#                      Floor2_z3_S1(RH%)  Floor2_z3_S1(degC)  Floor2_z3_S1(lux)  \
# Date
# 2018-07-01 00:00:00              68.22               29.30                0.0
# 2018-07-01 00:01:00              68.21               29.30                0.0
# 2018-07-01 00:02:00              68.24               29.29                0.0
# 2018-07-01 00:03:00              68.28               29.29                0.0
# 2018-07-01 00:04:00              68.30               29.29                0.0
#
#                      Floor2_z4_AC1(kW)  Floor2_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                0.0                  0.0
# 2018-07-01 00:01:00                0.0                  0.0
# 2018-07-01 00:02:00                0.0                  0.0
# 2018-07-01 00:03:00                0.0                  0.0
# 2018-07-01 00:04:00                0.0                  0.0
#
#                      Floor2_z4_Plug(kW)  Floor2_z4_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 0.0                NaN
# 2018-07-01 00:01:00                 0.0                NaN
# 2018-07-01 00:02:00                 0.0                NaN
# 2018-07-01 00:03:00                 0.0                NaN
# 2018-07-01 00:04:00                 0.0                NaN
#
#                      Floor2_z4_S1(degC)  Floor2_z4_S1(lux)  Floor3_z1_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                0.0
# 2018-07-01 00:01:00                 NaN                NaN                0.0
# 2018-07-01 00:02:00                 NaN                NaN                0.0
# 2018-07-01 00:03:00                 NaN                NaN                0.0
# 2018-07-01 00:04:00                 NaN                NaN                0.0
#
#                      Floor3_z1_AC2(kW)  Floor3_z1_AC3(kW)  ...  \
# Date                                                       ...
# 2018-07-01 00:00:00                0.0                0.0  ...
# 2018-07-01 00:01:00                0.0                0.0  ...
# 2018-07-01 00:02:00                0.0                0.0  ...
# 2018-07-01 00:03:00                0.0                0.0  ...
# 2018-07-01 00:04:00                0.0                0.0  ...
#
#                      Floor6_z2_Plug(kW)  Floor6_z2_S1(RH%)  \
# Date
# 2018-07-01 00:00:00
Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  0.0                0.03
# 2018-07-01 00:01:00                  0.0                0.03
# 2018-07-01 00:02:00                  0.0                0.05
# 2018-07-01 00:03:00                  0.0                0.14
# 2018-07-01 00:04:00                  0.0                0.13
#
#                      Floor7_z5_S1(RH%)  Floor7_z5_S1(degC)  Floor7_z5_S1(lux)
# Date
# 2018-07-01 00:00:00              66.72               28.93                0.0
# 2018-07-01 00:01:00              66.70               28.92                0.0
# 2018-07-01 00:02:00              66.70               28.92                0.0
# 2018-07-01 00:03:00              66.70               28.92                0.0
# 2018-07-01 00:04:00              66.70               28.92                0.0
#
# [5 rows x 192 columns]

# %% [markdown]
# ## **문제해결 프로세스 정의**
# ---
# > **문제정의**
#
# ```
# ▶ 스마트 빌딩 전력 비효율적 사용 (비정상적으로 많이 사용하는 포인트가 존재. limit 없음)
# ▶ 전력 비효율적 사용으로 인한 에너지 낭비
# ```
#
# > **기대효과**
#
# ```
# ▶ 전력 사용 이상 패턴 탐지하여 limit 부여로 효율적 전력 사용
# ▶ 에너지 소비 감소, 에너지 비용 절감
# ```
#
# > **해결방안**
#
# ```
# ▶ 전력 사용 이상 패턴 탐지하는 이상 탐지 모델링
# ▶ Session 1 🥉
#  - Data 전처리 및 EDA
# ▶ Session 2 🥈
#  - 주중 vs 주말 전력 사용 패턴 분석
# ▶ Session 3 🥇
#  - 이상 탐지 모델링 수행
# ```
#
# > **성과측정**
#
# ```
# ▶ 모델 활용 전/후 전력 사용량 모니터링
# ▶ 모델 활용 전/후 에너지 소비 금액 비교
# ```
#
# > **현업적용**
#
# ```
# ▶ BEMS에서 전력 사용량 데이터 수집
# ▶ 전력 사용 데이터 이상 탐지 모델에 Input
# ▶ 이상점 탐지 및 Alarm
# ```
#
# > **주요 코드 미리 살펴보기**
#
# ```
# ▶ Session 1 → read_pickle(), .str.contains(), .resample('H').mean()
# ▶ Session 2 → df['Date'].dt.weekday, sns.distplot(), .pivot_table()
# ▶ Session 3 → transpose(), Counter()
# ```

# %% [markdown]
# ## **🥉Session 1**
# **┗ Data 전처리 및 EDA**
# ---

# %% [markdown]
# ### · Data 전처리
# ---
# * 수집된 데이터의 기본 정보들을 확인
#
#   (1) Data shape(형태) 확인
#
#   (2) Data type 확인
#
#   (3) Null값 확인 (※ 빈 값의 Data)
#
#   (4) Outlier 확인 (※ 정상적인 범주를 벗어난 Data)

# %%
# ▶ Data 형태 확인
# ▶ 790560 row, 192 col로 구성됨
print('df :', df.shape)
# Out:
# df : (790560, 192)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 790560 entries, 2018-07-01 00:00:00 to 2019-12-31 23:59:00
# Columns: 192 entries, Floor1_z1_Light(kW) to Floor7_z5_S1(lux)
# dtypes: float64(192)
# memory usage: 1.1 GB

# %%
# ▶ Data type 확인
df.iloc[:,0:20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 790560 entries, 2018-07-01 00:00:00 to 2019-12-31 23:59:00
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Floor1_z1_Light(kW)  788169 non-null  float64
#  1   Floor1_z1_Plug(kW)   789459 non-null  float64
#  2   Floor1_z2_AC1(kW)    788231 non-null  float64
#  3   Floor1_z2_AC2(kW)    788355 non-null  float64
#  4   Floor1_z2_AC3(kW)    788354 non-null  float64
#  5   Floor1_z2_AC4(kW)    788354 non-null  float64
#  6   Floor1_z2_Light(kW)  788516 non-null  float64
#  7   Floor1_z2_Plug(kW)   760031 non-null  float64
#  8   Floor1_z3_Light(kW)  789447 non-null  float64
#  9   Floor1_z3_Plug(kW)   788355 non-null  float64
#  10  Floor1_z4_Light(kW)  789433 non-null  float64
#  11  Floor2_z1_AC1(kW)    760318 non-null  float64
#  12  Floor2_z1_Light(kW)  789492 non-null  float64
#  13  Floor2_z1_Plug(kW)   789487 non-null  float64
#  14  Floor2_z1_S1(RH%)    515922 non-null  float64
#  15  Floor2_z1_S1(degC)   515922 non-null  float64
#  16  Floor2_z1_S1(lux)    515922 non-null  float64
#  17  Floor2_z2_AC1(kW)    760084 non-null  float64
#  18  Floor2_z2_AC10(kW)   789417 non-null  float64
#  19  Floor2_z2_AC11(kW)   789417 non-null  float64
# dtypes: float64(20)
# memory usage: 126.7 MB

# %%
# ▶ Null 값 확인
print(df.isnull().sum())
# Out:
# Floor1_z1_Light(kW)      2391
# Floor1_z1_Plug(kW)       1101
# Floor1_z2_AC1(kW)        2329
# Floor1_z2_AC2(kW)        2205
# Floor1_z2_AC3(kW)        2206
#                         ...
# Floor7_z5_Light(kW)      4525
# Floor7_z5_Plug(kW)       4849
# Floor7_z5_S1(RH%)      281766
# Floor7_z5_S1(degC)     281766
# Floor7_z5_S1(lux)      281767
# Length: 192, dtype: int64

# %%
# ▶ Null 값 데이터 출력
df[df.isnull()].head()
# Out:
#                      Floor1_z1_Light(kW)  Floor1_z1_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor1_z2_AC1(kW)  Floor1_z2_AC2(kW)  Floor1_z2_AC3(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                NaN                NaN
# 2018-07-01 00:01:00                NaN                NaN                NaN
# 2018-07-01 00:02:00                NaN                NaN                NaN
# 2018-07-01 00:03:00                NaN                NaN                NaN
# 2018-07-01 00:04:00                NaN                NaN                NaN
#
#                      Floor1_z2_AC4(kW)  Floor1_z2_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor1_z2_Plug(kW)  Floor1_z3_Light(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                  NaN
# 2018-07-01 00:01:00                 NaN                  NaN
# 2018-07-01 00:02:00                 NaN                  NaN
# 2018-07-01 00:03:00                 NaN                  NaN
# 2018-07-01 00:04:00                 NaN                  NaN
#
#                      Floor1_z3_Plug(kW)  Floor1_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                  NaN
# 2018-07-01 00:01:00                 NaN                  NaN
# 2018-07-01 00:02:00                 NaN                  NaN
# 2018-07-01 00:03:00                 NaN                  NaN
# 2018-07-01 00:04:00                 NaN                  NaN
#
#                      Floor2_z1_AC1(kW)  Floor2_z1_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor2_z1_Plug(kW)  Floor2_z1_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor2_z1_S1(degC)  Floor2_z1_S1(lux)  Floor2_z2_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor2_z2_AC10(kW)  Floor2_z2_AC11(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                 NaN
# 2018-07-01 00:01:00                 NaN                 NaN
# 2018-07-01 00:02:00                 NaN                 NaN
# 2018-07-01 00:03:00                 NaN                 NaN
# 2018-07-01 00:04:00                 NaN                 NaN
#
#                      Floor2_z2_AC12(kW)  Floor2_z2_AC13(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                 NaN
# 2018-07-01 00:01:00                 NaN                 NaN
# 2018-07-01 00:02:00                 NaN                 NaN
# 2018-07-01 00:03:00                 NaN                 NaN
# 2018-07-01 00:04:00                 NaN                 NaN
#
#                      Floor2_z2_AC14(kW)  Floor2_z2_AC2(kW)  Floor2_z2_AC3(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor2_z2_AC4(kW)  Floor2_z2_AC5(kW)  Floor2_z2_AC6(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                NaN                NaN
# 2018-07-01 00:01:00                NaN                NaN                NaN
# 2018-07-01 00:02:00                NaN                NaN                NaN
# 2018-07-01 00:03:00                NaN                NaN                NaN
# 2018-07-01 00:04:00                NaN                NaN                NaN
#
#                      Floor2_z2_AC7(kW)  Floor2_z2_AC8(kW)  Floor2_z2_AC9(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                NaN                NaN
# 2018-07-01 00:01:00                NaN                NaN                NaN
# 2018-07-01 00:02:00                NaN                NaN                NaN
# 2018-07-01 00:03:00                NaN                NaN                NaN
# 2018-07-01 00:04:00                NaN                NaN                NaN
#
#                      Floor2_z2_Light(kW)  Floor2_z2_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor2_z2_S1(RH%)  Floor2_z2_S1(degC)  Floor2_z2_S1(lux)  \
# Date
# 2018-07-01 00:00:00                NaN                 NaN                NaN
# 2018-07-01 00:01:00                NaN                 NaN                NaN
# 2018-07-01 00:02:00                NaN                 NaN                NaN
# 2018-07-01 00:03:00                NaN                 NaN                NaN
# 2018-07-01 00:04:00                NaN                 NaN                NaN
#
#                      Floor2_z3_Light(kW)  Floor2_z3_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor2_z3_S1(RH%)  Floor2_z3_S1(degC)  Floor2_z3_S1(lux)  \
# Date
# 2018-07-01 00:00:00                NaN                 NaN                NaN
# 2018-07-01 00:01:00                NaN                 NaN                NaN
# 2018-07-01 00:02:00                NaN                 NaN                NaN
# 2018-07-01 00:03:00                NaN                 NaN                NaN
# 2018-07-01 00:04:00                NaN                 NaN                NaN
#
#                      Floor2_z4_AC1(kW)  Floor2_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor2_z4_Plug(kW)  Floor2_z4_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor2_z4_S1(degC)  Floor2_z4_S1(lux)  Floor3_z1_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor3_z1_AC2(kW)  Floor3_z1_AC3(kW)  ...  \
# Date                                                       ...
# 2018-07-01 00:00:00                NaN                NaN  ...
# 2018-07-01 00:01:00                NaN                NaN  ...
# 2018-07-01 00:02:00                NaN                NaN  ...
# 2018-07-01 00:03:00                NaN                NaN  ...
# 2018-07-01 00:04:00                NaN                NaN  ...
#
#                      Floor6_z2_Plug(kW)  Floor6_z2_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor6_z2_S1(degC)  Floor6_z2_S1(lux)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor6_z3_Light(kW)  Floor6_z3_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor6_z4_AC1(kW)  Floor6_z4_AC2(kW)  Floor6_z4_AC3(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                NaN                NaN
# 2018-07-01 00:01:00                NaN                NaN                NaN
# 2018-07-01 00:02:00                NaN                NaN                NaN
# 2018-07-01 00:03:00                NaN                NaN                NaN
# 2018-07-01 00:04:00                NaN                NaN                NaN
#
#                      Floor6_z4_AC4(kW)  Floor6_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor6_z4_Plug(kW)  Floor6_z4_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor6_z4_S1(degC)  Floor6_z4_S1(lux)  Floor6_z5_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor6_z5_Light(kW)  Floor6_z5_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor6_z5_S1(RH%)  Floor6_z5_S1(degC)  Floor6_z5_S1(lux)  \
# Date
# 2018-07-01 00:00:00                NaN                 NaN                NaN
# 2018-07-01 00:01:00                NaN                 NaN                NaN
# 2018-07-01 00:02:00                NaN                 NaN                NaN
# 2018-07-01 00:03:00                NaN                 NaN                NaN
# 2018-07-01 00:04:00                NaN                 NaN                NaN
#
#                      Floor7_z1_AC1(kW)  Floor7_z1_AC2(kW)  Floor7_z1_AC3(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                NaN                NaN
# 2018-07-01 00:01:00                NaN                NaN                NaN
# 2018-07-01 00:02:00                NaN                NaN                NaN
# 2018-07-01 00:03:00                NaN                NaN                NaN
# 2018-07-01 00:04:00                NaN                NaN                NaN
#
#                      Floor7_z1_AC4(kW)  Floor7_z1_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor7_z1_Plug(kW)  Floor7_z1_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor7_z1_S1(degC)  Floor7_z1_S1(lux)  Floor7_z2_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor7_z2_Light(kW)  Floor7_z2_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor7_z2_S1(RH%)  Floor7_z2_S1(degC)  Floor7_z2_S1(lux)  \
# Date
# 2018-07-01 00:00:00                NaN                 NaN                NaN
# 2018-07-01 00:01:00                NaN                 NaN                NaN
# 2018-07-01 00:02:00                NaN                 NaN                NaN
# 2018-07-01 00:03:00                NaN                 NaN                NaN
# 2018-07-01 00:04:00                NaN                 NaN                NaN
#
#                      Floor7_z3_Light(kW)  Floor7_z3_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor7_z4_AC1(kW)  Floor7_z4_Light(kW)  \
# Date
# 2018-07-01 00:00:00                NaN                  NaN
# 2018-07-01 00:01:00                NaN                  NaN
# 2018-07-01 00:02:00                NaN                  NaN
# 2018-07-01 00:03:00                NaN                  NaN
# 2018-07-01 00:04:00                NaN                  NaN
#
#                      Floor7_z4_Plug(kW)  Floor7_z4_S1(RH%)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN
#
#                      Floor7_z4_S1(degC)  Floor7_z4_S1(lux)  Floor7_z5_AC1(kW)  \
# Date
# 2018-07-01 00:00:00                 NaN                NaN                NaN
# 2018-07-01 00:01:00                 NaN                NaN                NaN
# 2018-07-01 00:02:00                 NaN                NaN                NaN
# 2018-07-01 00:03:00                 NaN                NaN                NaN
# 2018-07-01 00:04:00                 NaN                NaN                NaN
#
#                      Floor7_z5_Light(kW)  Floor7_z5_Plug(kW)  \
# Date
# 2018-07-01 00:00:00                  NaN                 NaN
# 2018-07-01 00:01:00                  NaN                 NaN
# 2018-07-01 00:02:00                  NaN                 NaN
# 2018-07-01 00:03:00                  NaN                 NaN
# 2018-07-01 00:04:00                  NaN                 NaN
#
#                      Floor7_z5_S1(RH%)  Floor7_z5_S1(degC)  Floor7_z5_S1(lux)
# Date
# 2018-07-01 00:00:00                NaN                 NaN                NaN
# 2018-07-01 00:01:00                NaN                 NaN                NaN
# 2018-07-01 00:02:00                NaN                 NaN                NaN
# 2018-07-01 00:03:00                NaN                 NaN                NaN
# 2018-07-01 00:04:00                NaN                 NaN                NaN
#
# [5 rows x 192 columns]

# %%
# ▶ Outlier 확인
df.describe()
# Out:
#        Floor1_z1_Light(kW)  Floor1_z1_Plug(kW)  Floor1_z2_AC1(kW)  \
# count        788169.000000       789459.000000      788231.000000
# mean              6.374115            2.431081          28.044690
# std               8.579784            4.690076          22.237263
# min               0.000000            0.000000           0.000000
# 25%               0.010000            0.570000           0.030000
# 50%               0.020000            0.720000          44.140000
# 75%              12.220000            1.190000          46.880000
# max             134.970000           57.860000         131.550000
#
#        Floor1_z2_AC2(kW)  Floor1_z2_AC3(kW)  Floor1_z2_AC4(kW)  \
# count      788355.000000      788354.000000      788354.000000
# mean            5.098173           0.008349           0.007349
# std            12.804208           0.028453           0.008503
# min             0.000000           0.000000           0.000000
# 25%             0.020000           0.010000           0.000000
# 50%             0.020000           0.010000           0.010000
# 75%             0.030000           0.010000           0.010000
# max           798.720000          24.950000           0.060000
#
#        Floor1_z2_Light(kW)  Floor1_z2_Plug(kW)  Floor1_z3_Light(kW)  \
# count        788516.000000       760031.000000        789447.000000
# mean             10.326638           15.128056            21.823732
# std               4.508054            3.707549            13.521861
# min               0.000000            0.000000             0.000000
# 25%               6.980000           13.070000            12.910000
# 50%               9.040000           15.090000            19.130000
# 75%              14.090000           17.140000            26.110000
# max              55.280000           73.680000          4762.430000
#
#        Floor1_z3_Plug(kW)  Floor1_z4_Light(kW)  Floor2_z1_AC1(kW)  \
# count       788355.000000        789433.000000      760318.000000
# mean             1.202470            16.432264           8.537406
# std              0.673175            17.418154          13.752005
# min              0.000000             0.000000           0.000000
# 25%              0.810000             0.060000           0.000000
# 50%              0.980000            14.240000           0.000000
# 75%              1.700000            31.380000          20.090000
# max             22.220000           512.010000          59.610000
#
#        Floor2_z1_Light(kW)  Floor2_z1_Plug(kW)  Floor2_z1_S1(RH%)  \
# count        789492.000000       789487.000000      515922.000000
# mean              2.706336            1.107082          61.536675
# std               3.586820            1.322278           5.312889
# min               0.000000            0.000000          45.500000
# 25%               0.010000            0.200000          57.620000
# 50%               0.010000            0.310000          61.660000
# 75%               7.410000            2.300000          65.380000
# max              22.380000            9.820000          76.900000
#
#        Floor2_z1_S1(degC)  Floor2_z1_S1(lux)  Floor2_z2_AC1(kW)  \
# count       515922.000000      515922.000000      760084.000000
# mean            24.700101          27.906689           6.079580
# std              2.753097          35.093531           9.746783
# min             17.560000           0.000000           0.000000
# 25%             22.780000           0.000000           0.150000
# 50%             25.210000           0.000000           1.050000
# 75%             26.760000          71.000000          13.280000
# max             31.900000          96.000000          50.720000
#
#        Floor2_z2_AC10(kW)  Floor2_z2_AC11(kW)  Floor2_z2_AC12(kW)  \
# count       789417.000000            789417.0       789417.000000
# mean             0.414307                 0.0            0.007018
# std              0.498730                 0.0            0.088790
# min              0.000000                 0.0            0.000000
# 25%              0.000000                 0.0            0.000000
# 50%              0.000000                 0.0            0.000000
# 75%              1.010000                 0.0            0.000000
# max              7.420000                 0.0            1.440000
#
#        Floor2_z2_AC13(kW)  Floor2_z2_AC14(kW)  Floor2_z2_AC2(kW)  \
# count       789417.000000       789417.000000      787961.000000
# mean             0.043787            0.007122           0.628142
# std              0.255195            0.096448           0.527761
# min              0.000000            0.000000           0.000000
# 25%              0.000000            0.000000           0.230000
# 50%              0.000000            0.000000           0.250000
# 75%              0.000000            0.000000           1.170000
# max             10.300000            1.610000           2.430000
#
#        Floor2_z2_AC3(kW)  Floor2_z2_AC4(kW)  Floor2_z2_AC5(kW)  \
# count      787961.000000      787961.000000      789417.000000
# mean            0.421450           0.471542           0.978702
# std             0.439603           0.491381           0.585097
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.370000
# 50%             0.000000           0.000000           1.310000
# 75%             0.880000           0.990000           1.370000
# max             2.080000           2.040000          15.760000
#
#        Floor2_z2_AC6(kW)  Floor2_z2_AC7(kW)  Floor2_z2_AC8(kW)  \
# count      789417.000000      789417.000000      789417.000000
# mean            0.586040           0.654046           0.362112
# std             0.538441           0.410830           0.437781
# min             0.000000           0.000000           0.000000
# 25%             0.220000           0.000000           0.000000
# 50%             0.240000           0.870000           0.000000
# 75%             1.220000           0.940000           0.880000
# max             9.040000          10.340000           6.460000
#
#        Floor2_z2_AC9(kW)  Floor2_z2_Light(kW)  Floor2_z2_Plug(kW)  \
# count      789417.000000        789386.000000       789338.000000
# mean            0.727240             0.628621            0.179655
# std             0.456249             0.928320            0.218199
# min             0.000000             0.000000            0.000000
# 25%             0.000000             0.000000            0.050000
# 50%             0.970000             0.000000            0.070000
# 75%             1.040000             1.610000            0.280000
# max            12.000000            11.510000            8.080000
#
#        Floor2_z2_S1(RH%)  Floor2_z2_S1(degC)  Floor2_z2_S1(lux)  \
# count      530254.000000       530251.000000      530252.000000
# mean           65.020223           25.461552          16.402222
# std             6.360321            2.684973          29.185083
# min            41.810000           18.360000           0.000000
# 25%            60.950000           23.980000           0.000000
# 50%            64.360000           25.870000           0.000000
# 75%            68.840000           27.410000          30.000000
# max            88.960000           31.900000         138.000000
#
#        Floor2_z3_Light(kW)  Floor2_z3_Plug(kW)  Floor2_z3_S1(RH%)  \
# count        789489.000000       789490.000000      525741.000000
# mean              0.524215            0.328631          65.006414
# std               0.365073            0.211594           8.706516
# min               0.000000            0.000000          33.100000
# 25%               0.190000            0.240000          58.500000
# 50%               0.450000            0.300000          64.880000
# 75%               0.810000            0.370000          71.860000
# max              12.000000           12.630000          86.800000
#
#        Floor2_z3_S1(degC)  Floor2_z3_S1(lux)  Floor2_z4_AC1(kW)  \
# count       525740.000000      525737.000000      760249.000000
# mean            27.590986           2.681126           2.365327
# std              1.534118           3.002424           4.114365
# min             22.510000           0.000000           0.000000
# 25%             26.580000           0.000000           0.000000
# 50%             27.660000           2.000000           0.000000
# 75%             28.730000           5.000000           4.890000
# max             32.140000          16.000000          55.330000
#
#        Floor2_z4_Light(kW)  Floor2_z4_Plug(kW)  Floor2_z4_S1(RH%)  \
# count        787961.000000       789338.000000      422317.000000
# mean              0.596903            0.017949          72.856257
# std               0.835156            0.014659           6.459959
# min               0.000000            0.000000          44.570000
# 25%               0.000000            0.000000          70.450000
# 50%               0.000000            0.030000          73.850000
# 75%               1.570000            0.030000          76.850000
# max               3.770000            0.060000          89.810000
#
#        Floor2_z4_S1(degC)  Floor2_z4_S1(lux)  Floor3_z1_AC1(kW)  \
# count       422315.000000      422312.000000      719633.000000
# mean            23.548124          13.459210           0.002222
# std              3.310516          19.327194           0.060007
# min             16.100000           0.000000           0.000000
# 25%             20.850000           0.000000           0.000000
# 50%             24.500000           0.000000           0.000000
# 75%             25.790000          38.000000           0.000000
# max             31.900000          88.000000           2.350000
#
#        Floor3_z1_AC2(kW)  Floor3_z1_AC3(kW)  ...  Floor6_z2_Plug(kW)  \
# count      719633.000000      719633.000000  ...       688095.000000
# mean            0.006714           0.007167  ...            0.394684
# std             0.121764           0.092505  ...            0.409177
# min             0.000000           0.000000  ...            0.000000
# 25%             0.000000           0.000000  ...            0.120000
# 50%             0.000000           0.000000  ...            0.190000
# 75%             0.000000           0.000000  ...            0.620000
# max             5.420000           2.260000  ...            9.390000
#
#        Floor6_z2_S1(RH%)  Floor6_z2_S1(degC)  Floor6_z2_S1(lux)  \
# count      398223.000000       398223.000000      398223.000000
# mean           63.121235           25.379942          25.143113
# std             6.426343            2.210769          28.289080
# min            46.890000           18.150000           0.000000
# 25%            58.500000           24.310000           0.000000
# 50%            62.690000           25.750000           1.000000
# 75%            67.980000           26.890000          57.000000
# max            85.900000           32.700000          78.000000
#
#        Floor6_z3_Light(kW)  Floor6_z3_Plug(kW)  Floor6_z4_AC1(kW)  \
# count        688105.000000       688092.000000      686202.000000
# mean              0.907454            0.268794           0.002827
# std               0.794480            0.056454           0.062977
# min               0.000000            0.000000           0.000000
# 25%               0.050000            0.260000           0.000000
# 50%               0.950000            0.280000           0.000000
# 75%               1.640000            0.290000           0.000000
# max               8.360000           10.750000           1.860000
#
#        Floor6_z4_AC2(kW)  Floor6_z4_AC3(kW)  Floor6_z4_AC4(kW)  \
# count      686202.000000      686202.000000      688048.000000
# mean            0.017710           0.002941           3.670580
# std             0.201284           0.057286           8.573934
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max            11.560000           5.980000          59.550000
#
#        Floor6_z4_Light(kW)  Floor6_z4_Plug(kW)  Floor6_z4_S1(RH%)  \
# count        687072.000000       688094.000000      430727.000000
# mean              1.438686            0.368627          62.593711
# std               1.816313            0.471100           6.308863
# min               0.000000            0.000000          44.140000
# 25%               0.000000            0.070000          58.300000
# 50%               0.000000            0.120000          63.360000
# 75%               3.570000            0.590000          67.300000
# max              22.990000            8.010000          81.440000
#
#        Floor6_z4_S1(degC)  Floor6_z4_S1(lux)  Floor6_z5_AC1(kW)  \
# count       430726.000000      430727.000000      688023.000000
# mean            25.401429          13.793428           1.395081
# std              2.378024          18.448427           3.878661
# min             17.900000           0.000000           0.000000
# 25%             24.410000           0.000000           0.000000
# 50%             25.680000           0.000000           0.000000
# 75%             27.100000          38.000000           0.000000
# max             32.100000          53.000000          47.770000
#
#        Floor6_z5_Light(kW)  Floor6_z5_Plug(kW)  Floor6_z5_S1(RH%)  \
# count        686451.000000       687072.000000      426139.000000
# mean              0.825058            0.176628          63.967024
# std               1.073269            0.203658           5.368140
# min               0.000000            0.000000          47.780000
# 25%               0.000000            0.050000          60.510000
# 50%               0.000000            0.080000          64.110000
# 75%               2.010000            0.260000          67.800000
# max              13.530000            3.680000          82.600000
#
#        Floor6_z5_S1(degC)  Floor6_z5_S1(lux)  Floor7_z1_AC1(kW)  \
# count       426146.000000      426146.000000           785711.0
# mean            25.712094          18.050964                0.0
# std              2.129129          22.242353                0.0
# min             18.220000           0.000000                0.0
# 25%             24.830000           0.000000                0.0
# 50%             25.760000           2.000000                0.0
# 75%             27.360000          44.000000                0.0
# max             31.900000          73.000000                0.0
#
#        Floor7_z1_AC2(kW)  Floor7_z1_AC3(kW)  Floor7_z1_AC4(kW)  \
# count      785711.000000      785711.000000      760272.000000
# mean            0.061161           0.063215           8.468760
# std             0.099490           0.096755          14.721565
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.010000           0.000000
# 50%             0.010000           0.010000           0.000000
# 75%             0.110000           0.100000          18.260000
# max             2.510000           1.280000          49.990000
#
#        Floor7_z1_Light(kW)  Floor7_z1_Plug(kW)  Floor7_z1_S1(RH%)  \
# count        787562.000000       789351.000000      525332.000000
# mean              0.799035            0.186694          66.448911
# std               0.953989            0.221711           6.260551
# min               0.000000            0.000000          39.850000
# 25%               0.000000            0.050000          62.960000
# 50%               0.000000            0.070000          67.210000
# 75%               1.660000            0.310000          70.570000
# max               5.720000            3.380000          86.230000
#
#        Floor7_z1_S1(degC)  Floor7_z1_S1(lux)  Floor7_z2_AC1(kW)  \
# count       525330.000000      525275.000000      760268.000000
# mean            24.745537           5.911012           6.291657
# std              3.583945          13.494539          11.367846
# min             15.660000           0.000000           0.000000
# 25%             22.550000           0.000000           0.000000
# 50%             25.280000           1.000000           0.000000
# 75%             27.460000           3.000000           0.000000
# max             33.900000          69.000000          58.130000
#
#        Floor7_z2_Light(kW)  Floor7_z2_Plug(kW)  Floor7_z2_S1(RH%)  \
# count        787562.000000       787214.000000      529566.000000
# mean              1.184614            0.063888          66.999217
# std               1.298715            0.143971           6.425117
# min               0.000000            0.000000          39.790000
# 25%               0.000000            0.000000          63.210000
# 50%               0.000000            0.010000          67.670000
# 75%               2.630000            0.050000          71.450000
# max               8.050000            1.370000          86.900000
#
#        Floor7_z2_S1(degC)  Floor7_z2_S1(lux)  Floor7_z3_Light(kW)  \
# count       529567.000000      529563.000000        788364.000000
# mean            25.862875          13.526755             0.119963
# std              2.809632          16.909522             0.116695
# min             18.840000           0.000000             0.000000
# 25%             23.900000           0.000000             0.020000
# 50%             26.220000           1.000000             0.050000
# 75%             27.780000          34.000000             0.220000
# max             33.900000          53.000000             0.890000
#
#        Floor7_z3_Plug(kW)  Floor7_z4_AC1(kW)  Floor7_z4_Light(kW)  \
# count       786896.000000      760286.000000        782703.000000
# mean             0.180838           5.831359             1.789884
# std              0.081771          11.188107             1.919113
# min              0.000000           0.000000             0.000000
# 25%              0.180000           0.000000             0.040000
# 50%              0.210000           0.000000             0.910000
# 75%              0.220000           0.000000             4.110000
# max              1.120000          59.220000            12.350000
#
#        Floor7_z4_Plug(kW)  Floor7_z4_S1(RH%)  Floor7_z4_S1(degC)  \
# count       785711.000000      520547.000000       520548.000000
# mean             0.204866          65.469546           26.030862
# std              0.259866           7.562577            3.285628
# min              0.000000          37.620000           17.530000
# 25%              0.040000          60.260000           24.250000
# 50%              0.090000          65.520000           26.600000
# 75%              0.320000          71.360000           28.300000
# max              3.460000          88.600000           35.730000
#
#        Floor7_z4_S1(lux)  Floor7_z5_AC1(kW)  Floor7_z5_Light(kW)  \
# count      520544.000000      760292.000000        786035.000000
# mean           20.690122           2.426660             1.819549
# std            26.268080           5.113394             2.191139
# min             0.000000           0.000000             0.000000
# 25%             0.000000           0.000000             0.000000
# 50%             0.000000           0.000000             0.000000
# 75%            53.000000           0.000000             4.170000
# max            99.000000          53.340000            13.090000
#
#        Floor7_z5_Plug(kW)  Floor7_z5_S1(RH%)  Floor7_z5_S1(degC)  \
# count       785711.000000      508794.000000       508794.000000
# mean             0.067584          64.011238           26.459081
# std              0.139170           7.350331            2.784883
# min              0.000000          37.140000           19.140000
# 25%              0.000000          59.250000           25.110000
# 50%              0.030000          64.740000           26.900000
# 75%              0.090000          69.550000           28.480000
# max              2.170000          84.920000           34.400000
#
#        Floor7_z5_S1(lux)
# count      508793.000000
# mean           25.261790
# std            30.333159
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%            61.000000
# max            78.000000
#
# [8 rows x 192 columns]

# %%
# ▶ Leave columns with keyword of 'kW' (전력량에 해당하는 값만 보고자 함)
df_powerMeter = df.loc[:, df.columns.str.contains('kW')].copy()

# ▶ Sum up demands of all power meters
# ▶ mean(), std() 연산 시 : NaN은 분석 대상(population)에서 제외
df_powerMeter = df_powerMeter.sum(axis=1).rename('total_demand')

# %%
df_powerMeter.head()
# Out:
# Date
# 2018-07-01 00:00:00    176.261667
# 2018-07-01 01:00:00    177.300000
# 2018-07-01 02:00:00    177.048833
# 2018-07-01 03:00:00    175.129167
# 2018-07-01 04:00:00    183.175000
# Freq: H, Name: total_demand, dtype: float64

# %%
df_powerMeter = df_powerMeter.resample('H').mean() # 1시간 단위의 평균전력량 계산
df = pd.DataFrame(df_powerMeter)
df.head()
# Out:
#                      total_demand
# Date
# 2018-07-01 00:00:00    176.261667
# 2018-07-01 01:00:00    177.300000
# 2018-07-01 02:00:00    177.048833
# 2018-07-01 03:00:00    175.129167
# 2018-07-01 04:00:00    183.175000

# %% [markdown]
# ### · Data EDA
# ---
# * 데이터 특성 파악을 위한 초기 탐색

# %%
# ▶ 필요 없는 변수 사전 제거 
df.head()
# Out:
#                      total_demand
# Date
# 2018-07-01 00:00:00    176.261667
# 2018-07-01 01:00:00    177.300000
# 2018-07-01 02:00:00    177.048833
# 2018-07-01 03:00:00    175.129167
# 2018-07-01 04:00:00    183.175000

# %%
df.isnull().sum()
# Out:
# total_demand    0
# dtype: int64

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2018-07-01 00:00:00', freq='H'),
#  Timestamp('2019-12-31 23:00:00', freq='H'))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use(['dark_background'])

plt.figure(figsize=(24,5))
plt.plot(df.index, df['total_demand'], linestyle='-', color='lime'); ## 전체 데이터 >> 뭔가 일정한 패턴이 있어 보임

# %%
plt.figure(figsize=(24,5)) # 중간에 비어있는(19년2월경) 데이터를 자세히 확인 
plt.plot(df.index[4000:6000], df['total_demand'][4000:6000], linestyle='-', color='lime');

# %%
# ▶ 분포 확인 >> 봉우리가 2개. 혹시 주중/주말?
sns.distplot(df['total_demand']);

# %%
# ▶ 기술통계량 확인
df['total_demand'].describe()
# Out:
# count    13176.000000
# mean       241.545518
# std        174.861629
# min          0.000000
# 25%        124.390667
# 50%        163.905583
# 75%        278.471375
# max        879.319167
# Name: total_demand, dtype: float64

# %% [markdown]
# ## **🥈Session 2**
# **┗ 주중 vs 주말 전력사용 분석**
# ---

# %% [markdown]
# ### · 주말, 주중 col 생성
# ---

# %% [markdown]
# * 왜 주중/주말?
# - 빌딩 특성에 따라 사용패턴이 다를 것
# - 오피스는 주중이 많을 것이고, 쇼핑몰은 주말이 많을 것이고...
# - 나눠서 확인해보기로

# %%
df.head()
# Out:
#                      total_demand
# Date
# 2018-07-01 00:00:00    176.261667
# 2018-07-01 01:00:00    177.300000
# 2018-07-01 02:00:00    177.048833
# 2018-07-01 03:00:00    175.129167
# 2018-07-01 04:00:00    183.175000

# %%
# ▶ Date col 활용하기 위해 reset index
df = df.reset_index()
df.head()
# Out:
#                  Date  total_demand
# 0 2018-07-01 00:00:00    176.261667
# 1 2018-07-01 01:00:00    177.300000
# 2 2018-07-01 02:00:00    177.048833
# 3 2018-07-01 03:00:00    175.129167
# 4 2018-07-01 04:00:00    183.175000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13176 entries, 0 to 13175
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          13176 non-null  datetime64[ns]
#  1   total_demand  13176 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 206.0 KB

# %%
# ▶ .weekday()
# ▶ 0-월, 1-화, 2-수, 3-목, 4-금, 5-토, 6-일
df['weekday'] = df['Date'].dt.weekday
df.head()
# Out:
#                  Date  total_demand  weekday
# 0 2018-07-01 00:00:00    176.261667        6
# 1 2018-07-01 01:00:00    177.300000        6
# 2 2018-07-01 02:00:00    177.048833        6
# 3 2018-07-01 03:00:00    175.129167        6
# 4 2018-07-01 04:00:00    183.175000        6

# %%
# ▶ 주말 사용이 더 적다.
df.groupby('weekday')['total_demand'].mean()
# Out:
# weekday
# 0    270.624464
# 1    288.313251
# 2    287.580237
# 3    291.957873
# 4    288.574328
# 5    140.185027
# 6    124.116551
# Name: total_demand, dtype: float64

# %%
# ▶ 주중(1), 주말(0) 비교 
import numpy as np
df['workingday'] = np.where(df['weekday']>4, 0, 1)
df.head()
# Out:
#                  Date  total_demand  weekday  workingday
# 0 2018-07-01 00:00:00    176.261667        6           0
# 1 2018-07-01 01:00:00    177.300000        6           0
# 2 2018-07-01 02:00:00    177.048833        6           0
# 3 2018-07-01 03:00:00    175.129167        6           0
# 4 2018-07-01 04:00:00    183.175000        6           0

# %%
df['workingday'].value_counts()
# Out:
# 1    9408
# 0    3768
# Name: workingday, dtype: int64

# %%
# ▶ 주중, 주말 비교 
df.groupby('workingday')['total_demand'].mean()
# Out:
# workingday
# 0    132.099616
# 1    285.379718
# Name: total_demand, dtype: float64

# %% [markdown]
# ### · 주말, 주중 total demand 분포 비교
# ---

# %%
# ▶ 요일 비교
sns.distplot(df[df['weekday']==0]['total_demand'], label='Mon');
sns.distplot(df[df['weekday']==1]['total_demand'], label='Tue');
sns.distplot(df[df['weekday']==2]['total_demand'], label='Wed');
sns.distplot(df[df['weekday']==3]['total_demand'], label='Thr');
sns.distplot(df[df['weekday']==4]['total_demand'], label='Fri');
sns.distplot(df[df['weekday']==5]['total_demand'], label='Sat');
sns.distplot(df[df['weekday']==6]['total_demand'], label='Sun');
plt.legend()
plt.gcf().set_size_inches(15, 10)

# %%
# ▶ 평일 주말 비교
sns.distplot(df[df['workingday']==0]['total_demand'], label='weekend');
sns.distplot(df[df['workingday']==1]['total_demand'], label='weekday'); 
plt.legend()
plt.gcf().set_size_inches(15, 10)
# 평일은 봉우리가 2개. 지금 1시간단위 데이터이므로, 주중은 시간대에 따라 사용량이 크게 두 그룹으로 나뉘는 것으로 보임.

# %% [markdown]
# ### · 주말, 주중 peak time 분석
# ---

# %%
df.head()
# Out:
#                  Date  total_demand  weekday  workingday
# 0 2018-07-01 00:00:00    176.261667        6           0
# 1 2018-07-01 01:00:00    177.300000        6           0
# 2 2018-07-01 02:00:00    177.048833        6           0
# 3 2018-07-01 03:00:00    175.129167        6           0
# 4 2018-07-01 04:00:00    183.175000        6           0

# %%
# ▶ 주중, 주말 데이터 분할
df_weekday = df[df['workingday'] == 1]
df_weekend = df[df['workingday'] == 0]

len(df_weekday), len(df_weekend)
# Out:
# (9408, 3768)

# %%
df_weekday = df_weekday[['Date', 'total_demand']]
df_weekend = df_weekend[['Date', 'total_demand']]

# %%
df_weekday['total_demand'].describe(), df_weekend['total_demand'].describe()
# Out:
# (count    9408.000000
#  mean      285.379718
#  std       188.249323
#  min         0.000000
#  25%       140.788333
#  50%       206.049500
#  75%       446.556125
#  max       879.319167
#  Name: total_demand, dtype: float64, count    3768.000000
#  mean      132.099616
#  std        40.802913
#  min         0.000000
#  25%       103.849875
#  50%       127.354750
#  75%       152.914083
#  max       344.095667
#  Name: total_demand, dtype: float64)

# %% [markdown]
# ### └ Weekday

# %%
df_temp = df_weekday.reset_index(drop=True).copy()
df_temp['date'] = df_temp['Date'].dt.date    
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp
# Out:
#                     Date  total_demand        date  hour
# 0    2018-07-02 00:00:00    165.985333  2018-07-02     0
# 1    2018-07-02 01:00:00    161.674667  2018-07-02     1
# 2    2018-07-02 02:00:00    159.642667  2018-07-02     2
# 3    2018-07-02 03:00:00    161.676333  2018-07-02     3
# 4    2018-07-02 04:00:00    175.787333  2018-07-02     4
# ...                  ...           ...         ...   ...
# 9403 2019-12-31 19:00:00    120.144500  2019-12-31    19
# 9404 2019-12-31 20:00:00    124.547667  2019-12-31    20
# 9405 2019-12-31 21:00:00    104.895333  2019-12-31    21
# 9406 2019-12-31 22:00:00     95.204167  2019-12-31    22
# 9407 2019-12-31 23:00:00     91.057667  2019-12-31    23
#
# [9408 rows x 4 columns]

# %%
# ▶ 사용 패턴 분석을 위해 pivot table 활용
df_temp = df_weekday.reset_index(drop=True).copy()
df_temp['date'] = df_temp['Date'].dt.date    
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp_pivot = df_temp.pivot_table(index='hour', columns='date', values='total_demand')
df_temp_pivot.head(5)
# Out:
# date  2018-07-02  2018-07-03  2018-07-04  2018-07-05  2018-07-06  2018-07-09  \
# hour
# 0     165.985333  131.899000  151.461667  141.166833  167.399833  140.007667
# 1     161.674667  108.551333  150.612167  138.617000  167.501000  139.839833
# 2     159.642667  107.407500  153.343333  138.730333  167.161667  138.502333
# 3     161.676333  105.860000  153.721000  136.327667  163.560000  140.350167
# 3      94.470667   71.418833   71.384333  104.632667   76.039500  117.184000
# 4     104.058167   78.809833   80.912167  111.634000   85.792833  124.462667
#
# date  2019-12-17  2019-12-18  2019-12-19  2019-12-20  2019-12-23  2019-12-24  \
# hour
# 0     137.644500   72.199333  117.439833  149.476500  139.247833   86.558333
# 1     131.396000   75.069167  114.824500  150.325000  143.120833   75.298667
# 2     120.765667   76.125500  111.953500  149.157500  126.263333   77.450667
# 3     120.516333   77.136667  113.193000  148.031833  122.458000   80.151667
# 4     140.429333   86.064167  120.019333  160.514667  130.717167   87.901333
#
# date  2019-12-25  2019-12-26  2019-12-27  2019-12-30  2019-12-31
# hour
# 0     109.984833  137.489667  126.705667  118.726667   92.033167
# 1     107.026667  127.115167  129.223333  120.385667   95.978000
# 2     105.883667  125.716500  127.541000  117.430833  111.968333
# 3     106.931167  128.493000  128.227333  112.530333  111.060333
# 4     111.930833  137.778667  138.229667  114.621667  117.493167
#
# [5 rows x 392 columns]

# %%
plt.style.use(['dark_background'])
df_temp_pivot.plot(figsize=(15,5),color='white',alpha=0.1,legend=False);
plt.xticks(range(0,24));

# %% [markdown]
# * 주중에는 8-9시, 13-14시경에 각각 피크타임으로 관찰됨.
# > 해당 시간대에는 사용 전력량이 매우 높은 경우가 존재하며, 해당 건에 대해 전력사용량을 최적화하거나 limit을 줄 경우 효율성이 높아질 것으로 기대

# %% [markdown]
# ### └ Weekend

# %%
# ▶ 사용 패턴 분석을 위해 pivot table 활용
df_temp = df_weekend.reset_index(drop=True).copy()
df_temp['date'] = df_temp['Date'].dt.date    
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp_pivot = df_temp.pivot_table(index='hour', columns='date', values='total_demand')
df_temp_pivot.head(5)
# Out:
# date  2018-07-01  2018-07-07  2018-07-08  2018-07-14  2018-07-15  2018-07-21  \
# hour
# 0     176.261667    183.5755  152.437833  131.714000  118.678167  134.769667
# 1     177.300000    182.4065  147.046000  107.378333  119.999333  134.711000
# 2     177.048833    180.1735  145.518333  109.976167   73.414833  134.337500
# 3     175.129167    180.9995  146.349500  108.467500   82.215000  135.613167
# 4     183.175000    191.8360  156.714000  116.965167   92.500000  144.541833
#
# date  2018-07-22  2018-07-28  2018-07-29  2018-08-04  2018-08-05  2018-08-11  \
# hour
# 0     123.540667    139.7420  172.895500    207.3800  207.968000  218.697500
# 1     123.246500    140.4690  168.073000    208.1165  208.049667  215.978333
# 2     123.306667    139.8640  165.240333    205.8855  203.118333  214.078000
# 3     122.910833    140.1520  168.140167    205.4945  199.730667  214.040000
# 4     132.142167    150.6375  179.200167    215.2050  211.504667  223.146000
#
# date  2018-08-12  2018-08-18  2018-08-19  2018-08-25  2018-08-26  2018-09-01  \
# hour
# 0     156.811000  195.737667  142.667167  138.152833  110.300167  135.267000
# 1     156.738667  196.001167  143.518833  137.564500  111.185667  137.016000
# 2     156.286833  197.829667  147.732667  137.645167  108.587167  135.956667
# 3     157.184500  197.393000  148.852333  136.300500  108.709500  135.920167
# 4     164.436500  199.805667  137.068667  136.985500  109.721500  145.191000
# %%
plt.style.use(['dark_background'])
df_temp_pivot.plot(figsize=(15,5),color='white',alpha=0.1,legend=False);
plt.xticks(range(0,24));

# %% [markdown]
# * 주말은 특별한 피크타임이 존재하지 않으나, 낮시간대에 거의 평일만큼 사용량이 높았던 날도 분명히 있음. (흐리게 보이는 선)
# 얘네가 이상케이스일 것으로 보임. 탐지할 필요가 있음.
#
#
# (+) 저렇게 모든 날짜/시간에 대한 선을 그렸을 때 장점
# > 만약 시간대별 일평균 수치를 구했을 경우에는, 일별 차이가 퉁쳐지기 때문에 위 그래프처럼 이상치에 해당하는 것들을 눈으로 확인하기 어려움. 위에처럼 그렸기 때문에 흐린 선들을 이상 케이스로 확인할 수 있는 것이다

# %% [markdown]
# ## **🥇Session 3**
# **┗ 이상탐지 모델링**
# ---

# %% [markdown]
# ### · Weekday(주중) 전력사용 이상탐지
# ---

# %%
df_weekday.head(5)
# Out:
#                   Date  total_demand
# 24 2018-07-02 00:00:00    165.985333
# 25 2018-07-02 01:00:00    161.674667
# 26 2018-07-02 02:00:00    159.642667
# 27 2018-07-02 03:00:00    161.676333
# 28 2018-07-02 04:00:00    175.787333

# %%
# ▶ 사용 패턴 분석을 위해 pivot table 활용
df_temp = df_weekday.reset_index(drop=True).copy()
df_temp['date'] = df_temp['Date'].dt.date    
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp_pivot = df_temp.pivot_table(index='hour', columns='date', values='total_demand')
df_temp_pivot.head(5)
# Out:
# date  2018-07-02  2018-07-03  2018-07-04  2018-07-05  2018-07-06  2018-07-09  \
# hour
# 0     165.985333  131.899000  151.461667  141.166833  167.399833  140.007667
# 1     161.674667  108.551333  150.612167  138.617000  167.501000  139.839833
# 2     159.642667  107.407500  153.343333  138.730333  167.161667  138.502333
# 3     161.676333  105.860000  153.721000  136.327667  163.560000  140.350167
# 4     175.787333  125.858333  166.073167  147.561333  178.709167  159.472167
#
# date  2018-07-10  2018-07-11  2018-07-12  2018-07-13  2018-07-16  2018-07-17  \
# hour
# 0     121.010667  123.411333  142.624667  156.394333   83.575000  151.423000
# 1     119.471167  123.094500  142.030000  148.799167   84.547667  146.478000
# 2     118.479000  123.527833  141.195833  149.541500   85.148000  143.936667
# 3     118.955000  123.304833  138.651167  150.007833   89.342500  131.275833
# 4     137.257167  142.823167  160.063500  165.558000  114.261833  145.013833
#
# date  2018-07-18  2018-07-19  2018-07-20  2018-07-23  2018-07-24  2018-07-25  \
# hour
# 0     104.509500  125.621000  146.721833  122.806833  158.990667  125.614167
# 1     103.142500  123.801667  146.342667  122.702500  159.769833  126.414833
# 2     104.334167  123.024667  147.209500  122.232833  164.664167  126.647333
# 3      99.423667  121.874333  147.142000  121.305167  164.294500  127.465167
# 4     112.019667  141.115000  162.604000  138.893333  183.688167  145.123833
#
# date  2018-07-26  2018-07-27  2018-07-30  2018-07-31  2018-08-01  2018-08-02  \
# hour
# 0     190.626333  150.542667  180.232000  131.202500  171.845000  176.112667
# 1     163.386667  151.080500  178.390167  129.882500  170.964667  152.226500
# 복잡한 방식보다는 명확하고 심플한 방법을 사용하는 것도 방법.

# %%
# ▶ UB, LB 계산을 위해 평균 및 표준편차 구하기 
df_temp_pivot['mean'] =  df_temp_pivot.apply(np.mean, axis=1)
df_temp_pivot['std'] = df_temp_pivot.apply(np.std, axis=1)
# df_temp_pivot[['mean', 'std']].head(5)
df_temp_pivot.head()
# Out:
# date  2018-07-02  2018-07-03  2018-07-04  2018-07-05  2018-07-06  2018-07-09  \
# hour
# 0     165.985333  131.899000  151.461667  141.166833  167.399833  140.007667
# 1     161.674667  108.551333  150.612167  138.617000  167.501000  139.839833
# 2     159.642667  107.407500  153.343333  138.730333  167.161667  138.502333
# 3     161.676333  105.860000  153.721000  136.327667  163.560000  140.350167
# 4     175.787333  125.858333  166.073167  147.561333  178.709167  159.472167
#
# date  2018-07-10  2018-07-11  2018-07-12  2018-07-13  2018-07-16  2018-07-17  \
# hour
# 0     121.010667  123.411333  142.624667  156.394333   83.575000  151.423000
# 1     119.471167  123.094500  142.030000  148.799167   84.547667  146.478000
# 2     118.479000  123.527833  141.195833  149.541500   85.148000  143.936667
# 3     118.955000  123.304833  138.651167  150.007833   89.342500  131.275833
# 4     137.257167  142.823167  160.063500  165.558000  114.261833  145.013833
#
# date  2018-07-18  2018-07-19  2018-07-20  2018-07-23  2018-07-24  2018-07-25  \
# hour
# 0     104.509500  125.621000  146.721833  122.806833  158.990667  125.614167
# 1     103.142500  123.801667  146.342667  122.702500  159.769833  126.414833
# 2     104.334167  123.024667  147.209500  122.232833  164.664167  126.647333
# 3      99.423667  121.874333  147.142000  121.305167  164.294500  127.465167
# 4     112.019667  141.115000  162.604000  138.893333  183.688167  145.123833
#
# date  2018-07-26  2018-07-27  2018-07-30  2018-07-31  2018-08-01  2018-08-02  \
# hour
# 0     190.626333  150.542667  180.232000  131.202500  171.845000  176.112667
# 1     163.386667  151.080500  178.390167  129.882500  170.964667  152.226500
# 2     167.328000  149.696167  177.402333  124.692500  169.149000  151.851333
# 3     173.608667  147.245667  142.279500  102.127667  173.585500  151.737167
# 4     179.963833  150.781167  149.425000  127.818500  190.018333  169.957333
#
# date  2018-08-03  2018-08-06  2018-08-07  2018-08-08  2018-08-09  2018-08-10  \
# hour
# 0     146.618500  177.550000  153.220000  163.270833  151.025000  204.192833
# 1     136.771667  176.072500  156.500167  161.386333  150.632667  199.099167
# 2     135.219833  174.910500  154.885167  163.271333  148.888333  197.372500
# 3     134.815000  175.453667  154.074500  162.151833  148.754667  196.705000
# 4     148.544500  189.014333  168.307000  177.920833  159.939833  207.010667
#
# date  2018-08-13  2018-08-14  2018-08-15  2018-08-16  2018-08-17  2018-08-20  \
# hour
# 0     167.943333  137.458000  164.800833  194.817000  231.351667  141.556833
# 1     170.530667  133.707333  163.564333  192.651833  241.282667  137.932167
# 2     171.696000  137.399667  162.418167  191.631333  241.634667  139.462833
# 3     172.642667  137.772500  160.975167  188.780500  241.504333  139.326000
# 4     183.007167  117.704000  177.161667  203.791500  251.277000  159.084333
#
# date  2018-08-21  2018-08-22  2018-08-23  2018-08-24  2018-08-27  2018-08-28  \
# hour
# 0     138.166167  101.663000   89.364667  118.135167  104.041333   78.414167
# 1     137.908333  100.644000   88.543167  117.937500  100.583000   64.963167
# 2     129.467000  101.804833   87.278000  109.949667   94.092333   68.970500
# 3     128.014667   99.963333   88.263333  110.414833   94.470667   71.418833
# 4     134.962667  110.028333   95.528333  117.595000  104.058167   78.809833
#
# date  2019-12-11  2019-12-12  2019-12-13  2019-12-16  2019-12-17  2019-12-18  \
# hour
# 0      77.881333  104.450167   82.194000  115.944167  137.644500   72.199333
# 1      70.997500  103.523833   80.545667  117.051500  131.396000   75.069167
# 2      73.347167  101.429667   74.598000  115.975500  120.765667   76.125500
# 3      71.384333  104.632667   76.039500  117.184000  120.516333   77.136667
# 4      80.912167  111.634000   85.792833  124.462667  140.429333   86.064167
#
# date  2019-12-19  2019-12-20  2019-12-23  2019-12-24  2019-12-25  2019-12-26  \
# hour
# 0     117.439833  149.476500  139.247833   86.558333  109.984833  137.489667
# 1     114.824500  150.325000  143.120833   75.298667  107.026667  127.115167
# 2     111.953500  149.157500  126.263333   77.450667  105.883667  125.716500
# 3     113.193000  148.031833  122.458000   80.151667  106.931167  128.493000
# 4     120.019333  160.514667  130.717167   87.901333  111.930833  137.778667
#
# date  2019-12-27  2019-12-30  2019-12-31        mean        std
# hour
# 0     126.705667  118.726667   92.033167  131.331907  28.409178
# 1     129.223333  120.385667   95.978000  128.410206  29.269964
# 2     127.541000  117.430833  111.968333  126.623550  29.416879
# 3     128.227333  112.530333  111.060333  125.687564  29.318483
# 4     138.229667  114.621667  117.493167  133.950628  30.126380
#
# [5 rows x 394 columns]

# %%
# ▶ UB, LB (표준편차에 몇을 곱할지는 조정하면서 진행)
df_temp_pivot['UB'] = df_temp_pivot['mean'] + 3*df_temp_pivot['std']
df_temp_pivot['LB'] = df_temp_pivot['mean'] - 3*df_temp_pivot['std']

# %%
plt.figure(figsize=(24,12));
df_temp_pivot.plot(figsize=(15,5),color='white',alpha=0.1,legend=False);
plt.plot(df_temp_pivot.index, df_temp_pivot['UB'], linestyle='--', color='red');
plt.plot(df_temp_pivot.index, df_temp_pivot['LB'] , linestyle='--', color='red');
plt.xticks(range(0,25));
plt.legend(['demand', 'Upper Bound', 'Lower Bound']);

# %%
# ▶ UB, LB (표준편차에 3을 곱했을땐 bound가 너무 넓어 2로 조정함)
df_temp_pivot['UB'] = df_temp_pivot['mean'] + 2*df_temp_pivot['std']
df_temp_pivot['LB'] = df_temp_pivot['mean'] - 2*df_temp_pivot['std']

# %%
plt.figure(figsize=(24,12));
df_temp_pivot.plot(figsize=(15,5),color='white',alpha=0.1,legend=False);
plt.plot(df_temp_pivot.index, df_temp_pivot['UB'], linestyle='--', color='red');
plt.plot(df_temp_pivot.index, df_temp_pivot['LB'] , linestyle='--', color='red');
plt.xticks(range(0,25));
plt.legend(['demand', 'Upper Bound', 'Lower Bound']);

# %%
# ▶ transpose 정상 데이터 변환
df_trans = df_temp_pivot.transpose()
df_trans.head()
# Out:
# hour                0           1           2           3           4   \
# date
# 2018-07-02  165.985333  161.674667  159.642667  161.676333  175.787333
# 2018-07-03  131.899000  108.551333  107.407500  105.860000  125.858333
# 2018-07-04  151.461667  150.612167  153.343333  153.721000  166.073167
# 2018-07-05  141.166833  138.617000  138.730333  136.327667  147.561333
# 2018-07-06  167.399833  167.501000  167.161667  163.560000  178.709167
#
# hour                5           6           7           8           9   \
# date
# 2018-07-02  170.425333  196.004333  388.554333  879.319167  790.151667
# 2018-07-03  136.880167  175.991667  339.218167  732.867333  672.135000
# 2018-07-04  167.860333  148.085667  345.777500  753.655333  618.404667
# 2018-07-05  155.378500  161.575333  310.369500  682.235500  604.616667
# 2018-07-06  181.884000  194.496500  331.265000  665.421333  587.234000
#
# hour                10          11          12          13          14  \
# date
# 2018-07-02  788.247000  623.208000  347.851667  830.949667  772.427500
# 2018-07-03  617.890667  496.177333  257.852333  672.045833  616.441333
# 2018-07-04  592.019167  464.300833  292.340167  700.819667  577.232667
# 2018-07-05  603.597333  477.598167  261.235667  696.772833  584.519000
# 2018-07-06  597.176500  472.711167  250.686167  648.317000  580.543833
#
# hour                15          16          17          18          19  \
# date
# 2018-07-02  680.769833  505.436167  262.390833  242.319833  226.239000
# 2018-07-03  606.372000  470.374000  281.021667  361.238333  352.938833
# 2018-07-04  582.802000  436.875333  231.310167  264.898667  249.956833
# 2018-07-05  601.417000  453.814500  268.385167  327.930333  308.598833
# 2018-07-06  565.802500  466.915333  353.154833  472.957500  415.926167
#
# hour                20          21          22          23
# date
# 2018-07-02  166.146000  144.235000  137.935000  131.790500
# 2018-07-03  254.252000  172.006167  154.113833  151.615833
# 2018-07-04  201.979167  189.537833  155.803000  140.610333
# 2018-07-05  212.896667  186.486000  215.566833  179.268167
# 2018-07-06  314.470000  277.834833  229.721000  209.454500

# %%
# ▶ 0 hr Anomaly Detection (0시에 이상치가 발생했던 날짜를 조회)
df_trans[df_trans.loc[:,0] > df_trans.loc['UB',0]].index.astype(str)
# Out:
# Index(['2018-07-26', '2018-08-10', '2018-08-16', '2018-08-17', '2018-10-05',
#        '2019-02-12', '2019-05-22'],
#       dtype='object', name='date')

# %%
# ▶ for 문
date_list = []

for i in df_trans.columns :
  ap = df_trans[df_trans.loc[:,i] > df_trans.loc['UB',i]].index.astype(str)
  date_list.extend(ap)

# %%
date_list[0:5]
# Out:
# ['2018-07-26', '2018-08-10', '2018-08-16', '2018-08-17', '2018-10-05']

# %%
# ▶ 2018-08-16일이 24시간 중 10회가 이상 탐지 됨
from collections import Counter
print(Counter(date_list))
# Out:
# Counter({'2018-08-16': 10, '2018-10-05': 9, '2018-08-10': 8, '2018-08-09': 7, '2018-07-06': 7, '2018-08-17': 6, '2019-05-22': 5, '2018-08-21': 5, '2019-05-21': 4, '2018-08-03': 4, '2018-08-15': 4, '2018-09-12': 3, '2018-09-13': 3, '2018-09-25': 3, '2019-05-31': 3, '2019-07-04': 3, '2019-02-12': 2, '2019-01-10': 2, '2018-07-20': 2, '2018-07-02': 2, '2019-04-22': 2, '2019-04-30': 2, '2019-05-03': 2, '2019-05-02': 2, '2018-10-11': 2, '2019-02-11': 2, '2019-08-22': 2, '2018-07-26': 1, '2019-02-08': 1, '2018-07-13': 1, '2018-08-08': 1, '2019-02-14': 1, '2018-09-28': 1, '2019-06-04': 1, '2019-06-05': 1, '2019-08-20': 1, '2019-04-29': 1, '2018-07-23': 1, '2019-04-24': 1, '2019-05-01': 1, '2019-05-07': 1, '2019-05-16': 1, '2019-05-27': 1, '2019-05-28': 1, '2018-07-03': 1, '2018-07-24': 1, '2018-10-04': 1, '2019-05-29': 1, '2019-07-05': 1, '2018-07-12': 1, '2019-06-27': 1, '2018-07-25': 1})

# %%
# ▶ 2018-08-16일 확인하기
df_train_reset = df_trans.reset_index()
df_train_reset['date'] = df_train_reset['date'].astype(str)
abnormal_date = df_train_reset[df_train_reset['date'] == '2018-08-16'].transpose()
abnormal_date = abnormal_date.drop(['date'], axis=0)
abnormal_date
# Out:
#               33
# hour
# 0        194.817
# 1     192.651833
# 2     191.631333
# 3       188.7805
# 4       203.7915
# 5     222.684333
# 6       162.2945
# 7     311.664833
# 8     619.444667
# 9     569.418833
# 10      532.5705
# 11    447.769667
# 12      238.0745
# 13      621.3385
# 14      562.6905
# 15    539.391333
# 16       423.889
# 17    325.163667
# 18    347.898833
# 19    343.272833
# 20    298.463667
# 21    277.070333
# 22    243.079667
# 23       230.754

# %%
plt.figure(figsize=(24,12)); # 언제 bound를 넘었는지 확인
abnormal_date.plot(figsize=(15,5),color='white',legend=False);
plt.plot(df_temp_pivot.index, df_temp_pivot['UB'], linestyle='--', color='red');
plt.plot(df_temp_pivot.index, df_temp_pivot['LB'] , linestyle='--', color='red');
plt.xticks(range(0,24));
plt.legend(['demand', 'Upper Bound', 'Lower Bound']);

# %% [markdown]
# * 왜 이 날 야간 및 새벽5시에 사용량이 높았는지 후속분석 필요

# %% [markdown]
# (+) 그런데, 엄밀히 말하면 3-sigma rule 적용하기 위해서는 정규성이 가정되어야 함 (사실 이게 큰 한계라고 했음)
# - 시간대별 rule 적용중 >> 각 시간대의 전력소비량 분포가 정규성을 만족해야 함
# - 과연 실제로 정규성을 충족할까?

# %%
# 정규성 검정 - Shapiro-Wilk Test
# (h0: 해당 데이터가 정규성을 충족한다.)
import numpy as np
from scipy.stats import shapiro

hour_list = sorted(df_temp['hour'].unique())

for hour in hour_list:
  tmp = df_temp[df_temp['hour']==hour]
  shapiro_test = shapiro(tmp['total_demand'])
  pvalue = shapiro_test.pvalue
  print(f'{hour}시 p-value = {pvalue}')
# Out:
# 0시 p-value = 0.0015192428836598992
# 1시 p-value = 0.0002902723790612072
# 2시 p-value = 0.00023479438095819205
# 3시 p-value = 0.00011470166646176949
# 4시 p-value = 0.0007782406755723059
# 5시 p-value = 0.015954401344060898
# 6시 p-value = 0.00037063000490888953
# 7시 p-value = 1.4032818398845848e-05
# 8시 p-value = 8.746015199775003e-20
# 9시 p-value = 1.1298964567035462e-18
# 10시 p-value = 1.516078960563728e-18
# 11시 p-value = 4.347473115989358e-19
# 12시 p-value = 2.281187391761641e-12
# 13시 p-value = 1.3767113316601546e-19
# 14시 p-value = 1.5994388105767954e-18
# 15시 p-value = 5.363149578579438e-19
# 16시 p-value = 1.6165126456005024e-18
# 17시 p-value = 0.0031444551423192024
# 18시 p-value = 0.0023389323614537716
# 19시 p-value = 0.12928764522075653
# 20시 p-value = 0.03803810849785805
# 21시 p-value = 0.007551232818514109
# 22시 p-value = 0.00011444065603427589
# 23시 p-value = 0.0008386324043385684

# %%
# 유일하게 정규성을 충족하는 19시의 데이터
h19 = df_temp[df_temp['hour']==19]

plt.figure(figsize=(8,4))
sns.distplot(h19['total_demand'])
plt.show()

# %%
# 낮시간대 데이터들은 대부분 정규성을 충족하지 못함
h8 = df_temp[df_temp['hour']==8]

plt.figure(figsize=(8,4))
sns.distplot(h8['total_demand'])
plt.show()

# %% [markdown]
# * 19시를 제외하고는 귀무가설 기각 >> 정규성을 충족하지 않는다.
# 그럼에도 3sigma rule을 그냥 적용해도 되는지?
# * 과연 이 방식으로 이상탐지를 하는게 적절한 방식인가?
# * 실무에서는 어떻게 사용되는지 찾아보자

# %% [markdown]
# ### · Weekend(주말) 전력사용 이상탐지
# ---

# %% [markdown]
# * 주중과 같은 방식으로 진행

# %%
df_weekend.head()
# Out:
#                  Date  total_demand
# 0 2018-07-01 00:00:00    176.261667
# 1 2018-07-01 01:00:00    177.300000
# 2 2018-07-01 02:00:00    177.048833
# 3 2018-07-01 03:00:00    175.129167
# 4 2018-07-01 04:00:00    183.175000

# %%
# df_weekend
df_temp = df_weekend.reset_index().copy()
df_temp['date'] = df_temp['Date'].dt.date    
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp_pivot = df_temp.pivot_table(index='hour', columns='date', values='total_demand')
df_temp_pivot.head(5)
# Out:
# date  2018-07-01  2018-07-07  2018-07-08  2018-07-14  2018-07-15  2018-07-21  \
# hour
# 0     176.261667    183.5755  152.437833  131.714000  118.678167  134.769667
# 1     177.300000    182.4065  147.046000  107.378333  119.999333  134.711000
# 2     177.048833    180.1735  145.518333  109.976167   73.414833  134.337500
# 3     175.129167    180.9995  146.349500  108.467500   82.215000  135.613167
# 4     183.175000    191.8360  156.714000  116.965167   92.500000  144.541833
#
# date  2018-07-22  2018-07-28  2018-07-29  2018-08-04  2018-08-05  2018-08-11  \
# hour
# 0     123.540667    139.7420  172.895500    207.3800  207.968000  218.697500
# 1     123.246500    140.4690  168.073000    208.1165  208.049667  215.978333
# 2     123.306667    139.8640  165.240333    205.8855  203.118333  214.078000
# 3     122.910833    140.1520  168.140167    205.4945  199.730667  214.040000
# 4     132.142167    150.6375  179.200167    215.2050  211.504667  223.146000
#
# date  2018-08-12  2018-08-18  2018-08-19  2018-08-25  2018-08-26  2018-09-01  \
# hour
# 0     156.811000  195.737667  142.667167  138.152833  110.300167  135.267000
# 1     156.738667  196.001167  143.518833  137.564500  111.185667  137.016000
# 2     156.286833  197.829667  147.732667  137.645167  108.587167  135.956667
# 3     157.184500  197.393000  148.852333  136.300500  108.709500  135.920167
# 4     164.436500  199.805667  137.068667  136.985500  109.721500  145.191000
# %%
# 정규성 검정 - Shapiro-Wilk Test
# (h0: 해당 데이터가 정규성을 충족한다.)
import numpy as np
from scipy.stats import shapiro

hour_list = sorted(df_temp['hour'].unique())

for hour in hour_list:
  tmp = df_temp[df_temp['hour']==hour]
  shapiro_test = shapiro(tmp['total_demand'])
  pvalue = shapiro_test.pvalue
  print(f'{hour}시 p-value = {pvalue}')
# Out:
# 0시 p-value = 3.920450762961991e-05
# 1시 p-value = 6.900220614625141e-05
# 2시 p-value = 0.0004145907878410071
# 3시 p-value = 0.0017015303019434214
# 4시 p-value = 0.001892352825962007
# 5시 p-value = 0.0014052808983251452
# 6시 p-value = 0.00040034728590399027
# 7시 p-value = 5.8394634834257886e-05
# 8시 p-value = 1.2524931092272595e-09
# 9시 p-value = 1.1361347560523427e-06
# 10시 p-value = 8.720365762826532e-09
# 11시 p-value = 1.4728334107871888e-08
# 12시 p-value = 1.0877973011247377e-07
# 13시 p-value = 1.5942920583711384e-07
# 14시 p-value = 2.4428936740150675e-07
# 15시 p-value = 4.952427161697415e-07
# 16시 p-value = 2.5437830686314555e-07
# 17시 p-value = 1.1356256436556578e-05
# 18시 p-value = 0.02867427095770836
# 19시 p-value = 0.3355254530906677
# 20시 p-value = 0.6147443056106567
# 21시 p-value = 0.11884981393814087
# 22시 p-value = 0.36343079805374146
# 23시 p-value = 0.5331056118011475

# %%
df_temp_pivot['mean'] =  df_temp_pivot.apply(np.mean, axis=1)
df_temp_pivot['std'] = df_temp_pivot.apply(np.std, axis=1)
df_temp_pivot[['mean', 'std']].head(5)
# Out:
# date        mean        std
# hour
# 0     129.335487  27.792407
# 1     127.376036  27.980207
# 2     125.984939  28.159846
# 3     126.209162  26.959907
# 4     133.955066  27.121575

# %%
df_temp_pivot['UB'] = df_temp_pivot['mean'] + 2*df_temp_pivot['std']
df_temp_pivot['LB'] = df_temp_pivot['mean'] - 2*df_temp_pivot['std']

plt.figure(figsize=(24,12));
df_temp_pivot.plot(figsize=(15,5),color='white',alpha=0.1,legend=False);
plt.plot(df_temp_pivot.index, df_temp_pivot['UB'], linestyle='--', color='red');
plt.plot(df_temp_pivot.index, df_temp_pivot['LB'] , linestyle='--', color='red');
plt.xticks(range(0,24));
plt.legend(['demand', 'Upper Bound', 'Lower Bound']);

# %%
df_trans = df_temp_pivot.transpose()
df_trans.head()
# Out:
# hour                0           1           2           3           4   \
# date
# 2018-07-01  176.261667  177.300000  177.048833  175.129167  183.175000
# 2018-07-07  183.575500  182.406500  180.173500  180.999500  191.836000
# 2018-07-08  152.437833  147.046000  145.518333  146.349500  156.714000
# 2018-07-14  131.714000  107.378333  109.976167  108.467500  116.965167
# 2018-07-15  118.678167  119.999333   73.414833   82.215000   92.500000
#
# hour                5           6           7           8           9   \
# date
# 2018-07-01  181.883667  160.375833  157.988667  142.767833  117.386000
# 2018-07-07  188.013833  142.066667  187.002333  257.087833  254.040000
# 2018-07-08  149.102000  117.651000  103.975167  100.827000  106.180667
# 2018-07-14   96.870333   85.058833   89.727667  181.448333  196.903333
# 2018-07-15   88.483667   85.390167   87.233667   95.005000   93.508333
#
# hour                10          11          12          13          14  \
# date
# 2018-07-01  118.581667  120.378000  123.815667  125.621000  125.465333
# 2018-07-07  272.682500  261.266000  238.355500  270.565500  254.757333
# 2018-07-08  113.984833  117.167667  121.729667  121.520667  121.693333
# 2018-07-14  197.827500  202.368000  135.220333  131.488333  125.614833
# 2018-07-15  109.978333  140.730000  130.622000  133.725000  141.560333
#
# hour                15          16          17          18          19  \
# date
# 2018-07-01  124.362667  136.078000  165.169000  188.052833  203.833000
# 2018-07-07  248.647000  221.785833  156.989333  173.552333  176.255167
# 2018-07-08  123.824833  161.735833  164.567833  184.599500  192.030667
# 2018-07-14  140.341333  136.259833  121.065833  162.927500  171.304167
# 2018-07-15  171.332667  158.700167  155.623667  177.117000  127.623833
#
# hour                20        21          22          23
# date
# 2018-07-01  215.054833  185.6340  180.671833  165.654667
# 2018-07-07  179.843333  176.7540  168.342833  146.343000
# 2018-07-08  191.702000  153.8390  151.763333  141.305000
# 2018-07-14  159.626000  138.6555  139.372667  129.932000
# 2018-07-15  126.165167  116.8995  116.349333   87.648000

# %%
# for 문
date_list = []

for i in df_trans.columns :
  ap = df_trans[df_trans.loc[:,i] > df_trans.loc['UB',i]].index.astype(str)
  date_list.extend(ap)

# %%
from collections import Counter
print(Counter(date_list))
# Out:
# Counter({'2018-08-04': 23, '2018-07-07': 13, '2019-05-04': 13, '2018-08-05': 11, '2018-08-11': 8, '2018-08-18': 8, '2018-07-21': 8, '2019-08-31': 7, '2019-07-20': 7, '2019-08-03': 7, '2019-05-05': 6, '2019-08-24': 6, '2018-09-08': 5, '2018-10-28': 5, '2019-07-06': 4, '2019-06-29': 4, '2018-10-07': 4, '2019-09-14': 3, '2019-07-27': 3, '2018-07-28': 3, '2018-07-01': 2, '2019-02-23': 2, '2019-07-13': 2, '2018-11-11': 2, '2019-05-25': 1, '2019-09-21': 1, '2018-07-22': 1, '2018-09-22': 1, '2018-09-23': 1, '2018-08-12': 1, '2019-03-03': 1})

# %%
df_train_reset = df_trans.reset_index()
df_train_reset['date'] = df_train_reset['date'].astype(str)
abnormal_date = df_train_reset[df_train_reset['date'] == '2018-07-07'].transpose()
abnormal_date = abnormal_date.drop(['date'], axis=0)
abnormal_date
# Out:
#                1
# hour
# 0       183.5755
# 1       182.4065
# 2       180.1735
# 3       180.9995
# 4        191.836
# 5     188.013833
# 6     142.066667
# 7     187.002333
# 8     257.087833
# 9         254.04
# 10      272.6825
# 11       261.266
# 12      238.3555
# 13      270.5655
# 14    254.757333
# 15       248.647
# 16    221.785833
# 17    156.989333
# 18    173.552333
# 19    176.255167
# 20    179.843333
# 21       176.754
# 22    168.342833
# 23       146.343

# %%
plt.figure(figsize=(24,12));
abnormal_date.plot(figsize=(15,5),color='white',legend=False);
plt.plot(df_temp_pivot.index, df_temp_pivot['UB'], linestyle='--', color='red');
plt.plot(df_temp_pivot.index, df_temp_pivot['LB'] , linestyle='--', color='red');
plt.xticks(range(0,25));
plt.legend(['demand', 'Upper Bound', 'Lower Bound']);
